# %% [markdown]
# # Local environment version
# The parts specific to the Google Colab version are commented out with #=#.<br>
# The parts added in the local environment have #++ at the end of the line.<br>
# I've added useful coding hints using Markdown blocks beginning with [HN], which means [Hints / Niigata-Univ H.Nishiyama version]<br>
# original: https://github.com/TMDU-AI/AI-yodosha<br>
# modified by H.Nishiyama, Niigata-Univ.<br>

# %% [markdown]
# # ローカル環境版
# Google Colab 版特有の部分は #=# でコメントアウトしています。<br>
# ローカル環境で追加した部分は行末に #++ が付いています。<br>
# [HN] で始まる Markdown ブロックを使用して、有用なコーディング ヒントを追加しました。これは  [Hints / Niigata-Univ H.Nishiyama version]を意味します。<br>
# オリジナル: https://github.com/TMDU-AI/AI-yodosha<br>
# 新潟大学 H.Nishiyama が改訂しました。<br>

# %% [markdown]
# # **0章　演習準備**

# %% [markdown]
# コード0-1　変数に足し算の値を代入

# %%
a = 3 + 3

# %% [markdown]
# コード0-2　変数の値の出力

# %%
a

# %% [markdown]
# コード0-3　複数行の入力

# %%
b = 1 + 3
b

# %% [markdown]
# コード0-4　変数名のみが複数行存在する際の出力結果

# %%
c = 2 + 2
c
d = 3 + 3
d

# %% [markdown]
# コード0-5　print関数を使った出力

# %%
c = 2 + 2
print(c)
d = 3 + 3
# 最後の行なのでdのみでも6というデータが出力されます
print(d)

# %% [markdown]
# コード0-6　Matplotlibを用いた折れ線グラフの描画

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [3, 4, 6]
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### コード0-7　#=# オリジナルコード：Google Driveのマウント
# #### #++ [HN]現在の作業ディレクトリ表示<br>
# ```%pwd``` はpythonのコマンドではなく、マジックコマンドといって、ipython（jupyter notebook）にて解釈される（擬似的な）OSレベルのコマンド<br>
# 参考：<a href="https://qiita.com/mgsk_2/items/437656b8ce42c03e41a6">Jupyter Notebook マジックコマンド自分的まとめ</a>

# %%
#=# from google.colab import drive
#=# drive.mount('/content/drive')
# %pwd #++

# %% [markdown]
# コード0-8　pandasを用いたファイルの読み込み

# %%
import pandas as pd
#=# test = pd.read_csv('/content/drive/MyDrive/sample.csv', encoding='utf-8')
test = pd.read_csv('sample.csv', encoding='utf-8') #++
print(test)
